# %% [markdown]
# # Run AI agent

# %%
# Install libraries if you already do not have them
#!pip install langchain langchain-openai langchain-community chromadb gradio requests

# %%
# For Colab Only
'''
import os
os.environ['PYTHONPATH'] = '/content/'
# For Colab Only
# !unzip /content/chat_system.zip
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OpenAI")
'''

# %%
# !python chat_system/app.py
